# %% [markdown]
# <br>
#
# # Bacia do Alto Tietê
#
# [![Repo](https://img.shields.io/badge/GitHub-repo-blue?logo=github&logoColor=f5f5f5)](https://github.com/open-geodata/sp_bh_at)

# %%
import open_geodata as geo

# %%
db = geo.data.DB(db='sp_bh_at')
db.list_data
# Out:
# ['geo.01_aprm',
#  'geo.06_bacia_alto_tiete',
#  'geo.16_hidrografia',
#  'geo.17_hidrografia_complementar',
#  'geo.45_subbacias',
#  'geo.57_area_protegida_revisao',
#  'geo.58_area_protegida_zona_amortecimento',
#  'geo.62_mov_massa_e_inundacao',
#  'geo.101_rmsp',
#  'geo.apps',
#  'geo.apps_hidrografia',
#  'geo.apps_nascentes',
#  'geo.áreas contaminadas e reabilitadas na ugrhi 6 - ano 2020',
#  'geo.comite_alto_tiete',
#  'geo.municípios da região metropolitana de são paulo',
#  'geo.municipios ugrhi 6',
#  'geo.reservatórios_rmsp']

# %%
gdf = geo.load_dataset(
    db='sp_bh_at', name='geo.06_bacia_alto_tiete'
)
gdf.head()
# Out:
# ...
#    OBJECTID                            BAT_DS   BAT_AR_KM2     Shape_Leng  \
# 0         1  Bacia Hidrográfica do Alto Tietê  5775.124205  672574.004504
#
#      Shape_Area                                           geometry
# 0  5.775124e+09  POLYGON ((-46.43567 -23.21886, -46.43494 -23.2...

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
